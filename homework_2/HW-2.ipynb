# %% [markdown]
# # Homework 2
# ## Daniel Hogan
# ## CUAHSI Virtual University

# %% [markdown]
# ## Question 1 (a)
# **How does the number of layers impact modeled snow water
# equivalent evolution? Are there certain times of year (or times of the
# snowmelt cycle) that are more sensitive than others?**

# %% [markdown]
# Figure 1: Plot showing model SWE output from different layering schemes.

# %% [markdown]
# ![layer_comparison.png](attachment:073145d4-92b7-4129-89f3-568cb445102b.png)

# %% [markdown]
# The above figure shows the modeled SWE result for each layering configuration. It appears the period of melt near the end of the season is the time when these different model runs diverge and where layering schemes become most important. The divergence appears to be exacerbated with greater SWE since these differences are more apparent in 2011 (where greater SWE is modeled) than 2012. Let's take a look at a close up of the 2011 and 2012 rapid melt period to look at the effects of each specific layering scheme.

# %% [markdown]
# Figures 2 and 3: Plots show modeled SWE during period of melt (April to July/August) for 2011 and 2012, respectively (note time scale differences)

# %% [markdown]
# ![layer_comparison_closeup_melt_2011.png](attachment:f569fb7b-a22a-41b4-b094-69943d3c1251.png)
# ![layer_comparison_closeup_melt_2012.png](attachment:c866c7a6-2bd7-427f-bf17-2540fb9facc7.png)

# %% [markdown]
# Comparing the figures above, it appears that the thin 2-layer method is most sensitive to this melt period in both model years. The standard CLM layering and Jordan1991 layering approach appear to match each other well in both model years. The thick 2-layer CLM approach appears to match the standard CLM and Jordan 1991 layering for the most part, but seems slightly more sensitive to the end season accumulation period in June 2011 (when compared to the other layering approaches) and holds onto snow slightly longer in 2012.

# %% [markdown]
# ## Question 1 (b)
# **How does the number of layers impact modeled snow density (snow water equivalent divided by snow depth)? Are there certain times of
# year (or times of the snowmelt cycle) that are more sensitive than
# others?**

# %% [markdown]
# Figure 4: Modeled snow density for layering schemes over 2011 and 2012

# %% [markdown]
# ![density.png](attachment:a4cf5c6d-7848-4dde-ada2-bda4f89749e5.png)

# %% [markdown]
# Areas of divergence that pop out seem to be the start and end of the snow seasons. Let's look further into those time periods.

# %% [markdown]
# **Figure 5: Modeled snow density for layering schemes during 2011 and 2012 melt periods (note time scale differences)**

# %% [markdown]
# ![layer_comparison_depth_melt.png](attachment:a15a101a-78d5-4d95-ac99-afb77a538082.png)

# %% [markdown]
# Comparing accross the two years, it appears that both years capture a time period where the schemes with greater than 2 layers (CLM or Jordan1991) have generally higher density. Near the end of the snow season, however, this relationship falls apart. In all, density does appear to be a great metric for evaluating snow layering techniques since differences are difficult to discern. Having stated this, I will look at the early season for both years to see if any differences are apparent.

# %% [markdown]
# **Figure 6: Modeled snow density for layering schemes during 2011 and 2012 accumulation periods**

# %% [markdown]
# ![layer_comparison_depth_accum.png](attachment:8586f07b-abd7-43c3-a447-062ce5a34da6.png)

# %% [markdown]
# Early season differences in density show up most clearly in the thick 2-layer scheme in 2012 and early WY 2011. This 2-layer scheme shows lower density compared to the other layering setups. However, if the beginning of WY 2011 is ignored, the difference between each layering scheme is minimal ac

# %% [markdown]
# ## Question 1 (c)
# **How does the number of layers impact snow surface temperature and
# the vertical profile of temperature through the snowpack? Are certain
# times of day or times of year more sensitive than others? When in the
# year do you see the greatest differences?**

# %% [markdown]
# **Figure 7: Snow Surface Temperature (Surface Temperature < 0) for each layering setup model run**

# %% [markdown]
# ![temperature.png](attachment:880b15e2-d3e2-4bbd-aa51-af61e12bc2e9.png)

# %% [markdown]
# Figure 7 shows a rolling averages run of snow surface temperature(SST, assigned as T<0). Note that data in the summer months SST does not exist, as all snow had melted by then. The thin 2-layer setup looks like it shows a lower surface temperature across both 2011 and 2012. Let's look at the winter season for each year a bit closer.

# %% [markdown]
# Figure 8: Winter SST comparison for 2011 and 2012 for different layering setups

# %% [markdown]
# ![layer_comparison_sst.png](attachment:98b82486-e994-4090-9843-52a0c39a7911.png)

# %% [markdown]
# The 2011 winter shows a much wider range in SST when compared to 2012 (Figure 8) most likely due to the much deeper snowpack present in 2011. These plots both show the thin 2-layer setup to have lower SST throughout the winter. The thick 2-layer model shows a slighly lower SST compared to the model runs with more than 2 layers. Both the CLM and Jordan1991 setups agree with each other rather well for both years.

# %% [markdown]
# Figure 9: Daily SST changes

# %% [markdown]
# ![layer_comparison_sst_D.png](attachment:5901792d-24f0-40d7-a690-f9be6f4c08f1.png)

# %% [markdown]
# Diurnal changes in SST are most sensitive in the thin 2-layer setup of the model, as the example data from 2011 shows above in Figure 9. The significant change in SST seen in this layer setup relative to the other setups can be explained by the fact that it takes much less energy to change the temperature of a thin surface layer than a thicker surface layer of snow. The thin layer has much less cold content and thus can change temperature rapidly with atmospheric conditions

# %% [markdown]
# Figure 10: Annual Diurnal changes in surface temperature (P.S. I had trouble adding colormap labels, the hovmoller method did not have colormap labels in the source code. Do we have a previous version of pysumma.plotting?)

# %% [markdown]
# ![surfac_temp_timing_2layer.png](attachment:ddb08682-6777-41db-b9d6-08a8864b8738.png)
# ![surfac_temp_timing_clm.png](attachment:aaf4c9d8-84e2-45d4-9894-db029a7e2ff4.png)
# ![surfac_temp_timing_jrdn.png](attachment:a6e4cb6a-9bbf-4649-8d29-465c331fe6e5.png)
# ![surfac_temp_timing_thick.png](attachment:259ae56f-113e-4721-b470-a27a54366bc8.png)

# %% [markdown]
# Figure 10 shows the diurnal and mothly changes in surface temperature. Since the thin 2-layer setup is most sensitive to

# %% [markdown]
# Figure 11: Layer temperature

# %% [markdown]
# ![layer_temp.png](attachment:06a6bcf5-e7b8-4dc2-9a40-183a288ec9b5.png)

# %% [markdown]
# Figure 11 shows the temperature of each layer over a 5-day period in January 2011.  All model runs show how layer temperature follows a diurnal cycle (warmer during day, cooler during night) and have the warmest layers near the soil-snow interface during the night. The model runs with more layers (top two plots in Figure 10) show temperature profiles for each layer that reflect heat moving through each successive layer as the layers above heat up, wheras the 2-layer model runs show quick changes in top layer temperature due to daily heating, and minimal bottom layer temperature changes. Heat seems to effect the bottom layer in the thin 2-layer model run more than the thick 2-layer model run because the thin layer has much less capacity to accept heat, and thus heat is transferred quicker to the lower layer.
#
# Figure 12: Layer temperature and snow depth (P.S. I had trouble changing colormap labels for these, I think there may be a bug looking at the source code)

# %% [markdown]
# ![Layer temperatures.png](attachment:31bb0a1b-d430-4203-bf2c-a91beb415c6f.png)

# %% [markdown]
# Figures 12 shows the SWE profile filled in by layer temperature for each layering setup. Although difficult to compare side-by-side, the greatest differences between the modeling setups is seen in the top layers. The top layers appear consistently cooler throughout both 2011 and 2012 winters for the CLM and Jordan modeling setups.

# %% [markdown]
# ## Question 1 (d)
# **Does the number of layers have an influence on any soil properties?
# Which and when?**

# %% [markdown]
# To evaluate effects on of layering on soil properties, I looked at matric head, soil baseflow, total runoff, soil water and ice content. I could not discern layering impacts on matric head or soil baseflow (figures available in code posted to Hydroshare). Soil water and ice content have an inverse relationship, clearly visible in winter: more ice content would stem from lower water content. During summer, as expected, no ice in soil exists (Figure 12). I decided to look closer at the periods where layering schemes diverge.

# %% [markdown]
# Figure 13: Soil Liquid Water and Ice Content Comparison - 2011 and 2012

# %% [markdown]
# ![layer_comparison_ice_water.png](attachment:707fa477-e43b-4193-b657-b3c2243ef340.png)

# %% [markdown]
# Figure 14: Soil Water Content - 2011 and 2012 Ablation Period

# %% [markdown]
# ![layer_comparison_water.png](attachment:739d360f-5f73-4c3c-9191-03b76297987b.png)

# %% [markdown]
# Figure 14 shows a discernable increase in liquid water content for both 2011 and 2012 in the thin 2-layer scheme, when compared to the other three schemes.

# %% [markdown]
# Figure 15: Soil Ice Content - 2011 and 2012 Ablation Period

# %% [markdown]
# ![layer_comparison_ice.png](attachment:0a146482-7ace-4187-8ed5-3137faaf852e.png)

# %% [markdown]
# Figure 15 shows a distinct underestimation of ice content for both 2011 and 2012 in the thin 2-layer scheme, when compared to the other three schemes. This appears to account for the relatively greater liquid water content values discussed above. However, I am not sure why 2012 shows significantly more ice content than 2011, while also showing an increase in ice content over time, especially given that snow melted out significantly earleir in 2012.

# %% [markdown]
# In summary, the thin 2-layer model run undershoots soil ice content and overshoots soil water content when compared to the other layering setups.

# %% [markdown]
# Fig 16: Comparing 4 other soil properties

# %% [markdown]
# ![soil_properties.png](attachment:0c5e67b8-888d-4b75-85a3-b8fe20408e18.png)

# %% [markdown]
# Figure 16 shows comparisons of each layer setup between four different soil properties: aquifer base flow, average routed runoff, ground flux and total runoff. Aquifer base flow remains 0 throughout the entire model simulation, so there is no effect of layering schemes on this metric. Average routed runoff and total runoff follow the same profile. Both of these metrics show a slight difference for the thin 2-layer setup. Early season melt supports the high relative runoff rates in May, but since the volume of water is removed from the system, the later season melt cannot support as high of a peak in total runoff as the other model setups. Ground flux appears to be lower for the thin 2-layer model in spring/summer 2011, but this same trend is not seen in 2012. In all, layering schemes appear to have the largest impact on runoff.

# %% [markdown]
# ## Question 1 (e)
# **Based on your analysis, how many layers would you recommend for a
# hydrology model and why? Would your answer vary for different
# locations or applications? Feel free to reference the plots you made to
# answer the questions above and to include plots using model output
# variables other than SWE, depth, and temperature if they help your
# discussion.**

# %% [markdown]
# I do not believe there is one answer to the question of how many layers would be best for a hydrology model, but from the analysis above, the thick 2-layer model appeared to match output well for SWE (figures 1-3), surface temperature (figures 7-9), and soil impacts (figures 10-13) with both the CLM and Jordan1991 layering setups. Since information on snow layers is not strictly necessary for hydrologic modeling, decreasing the complexity of the model by using less layers could allow for more efficiency when distributing the model over a larger area and could thus be better for hydrologic modeling. With respect to a thick or thin 2-layer model, I think this is where the location could make a difference. A thin layer setup for a location with a large snowpack could potentially prove too sensitive to mid-season ablation. I believe a thin 2-layer setup would be most appropriate in a location with low amounts of snow that is highly sensitive to melt. On the other hand,

# %% [markdown]
# ## Question 2
# **At this point, you should have partners for your final presentation and an
# idea what you want to present. Please list your partners’ name(s) and the
# planned outline/scope of your presentation here. [It is fine if the text in this
# section is duplicated between your assignment and your partner(s)
# assignments. Just make sure your answers to question 1 are your own.]**

# %% [markdown]
# I will be working with Hannah Van Dusen. We will run the SUMMA model after altering albedo parameters to approximate the effects of a wildfire on snow surface temperature, SWE, and other snow properties. We will attempt to encompass the function used in Gleason et. al 2016 to alter albedo and mimic post-wildfire albedo conditions by changing the maximum albedo, minimum albedo, albedo decay rate, and the albedo renewal term. We will also aim to compare the results of the variable albedo decay to the constant albedo decay.

# %% [markdown]
# ## References:
# - This homework used several examples provided in the pysumma_howto.ipynb jupyter notebook to produce figures.
